# %%
import pandas as pd

# %%
path = "grid_search_clip_scores_v2.csv"

# %%
df = pd.read_csv(path)

# %%
df = df[""]
# Out:
#      clip_score  elongation  compactness  opacity    duration  \
# 0      0.559228      0.1000      10.0000   0.1000  164.262227
# 1      0.730417      1.0000       1.0000   0.0100  171.189640
# 2      0.593477     10.0000       0.0100  10.0000  160.728970
# 3      0.733917      0.0010       0.1000  10.0000  170.172273
# 4      0.744115      0.1000       0.0001   0.0001  169.589780
# ..          ...         ...          ...      ...         ...
# 536    0.749896     10.0000       1.0000   0.0100  183.612341
# 537    0.609222     10.0000       0.1000   1.0000  156.917828
# 538    0.573648      0.0001       1.0000   0.0001  215.265639
# 539    0.814347      0.1000       0.0100   0.1000  175.066583
# 540    0.840663      0.0001      10.0000   0.0001  163.522334
#
#                     input_image_path  \
# 0     images/grid_search/image-7.png
# 1    images/grid_search/image-13.png
# 2     images/grid_search/image-7.png
# 3    images/grid_search/image-13.png
# ...
